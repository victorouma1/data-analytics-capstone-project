# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       6
#       7 url = f"https://rplumber.ilo.org/files/indicator/{DATASET_ID}.csv"
#       8
#       9 response = requests.get(url)
# ---> 10 response.raise_for_status()
#      11
#      12 df = pd.read_csv(StringIO(response.text))
#      13
#
# File c:\Users\victo\OneDrive\Documents\Data science course\data-analytics-capstone-project\env\Lib\site-packages\requests\models.py:1028, in Response.raise_for_status(self)
#    1023     http_error_msg = (
#    1024         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1025     )
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://rplumber.ilo.org/files/indicator/EAR_EMTM_SEX_CUR_NB_A.csv
